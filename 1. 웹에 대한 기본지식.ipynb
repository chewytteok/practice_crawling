# %%
from IPython.display import Image

# %% [markdown]
# HyperText Transfer Protocol : HTML 문서 등의 리소스를 전송하는 프로토콜
#
# 클라이언트 => HTTP요청(Get, Post 등) => 서버
# 서버 => HTTP 응답 => 서버

# %% [markdown]
# ### Get 요청 : 데이터를 URL에 포함하여 전달(주로 리소스 요청에 사용)
# - F12 를 누른 후 Network에서 확인 할 수 있음

# %%
Image(filename = "d:/data/get.png")

# %% [markdown]
# ### Post 요청 : 데이터를 Form data에 포함하여 전달(주로 로그인에 사용)
# - F12 를 누른 후 Network에서 확인 할 수 있음

# %%
Image(filename = "d:/data/post.png")

# %% [markdown]
# ### HTML (Hyper Text Markup Language
#
# - 웹사이트를 생성하기 위한 언어로 문서와 문서가 링크로 연결되어 있고, 태그를 사용하는 언어

# %%
Image(filename = "d:/data/html.png")

# %% [markdown]
# ### HTML 문서의 기본 블락
#
# 브라우저에 어덯게 렌더링(화면에 표시)될지 전달
#
# <태그명 속성1="속성값1" 속성2="속성값2">Value</태그명>
# <태그명 속성1="속성값1" 속성2="속성값2"/>

# %%
Image(filename = "d:/data/html_1.png")

# %% [markdown]
# 태그 출처 : https://www.donga.com/news/article/all/20131204/59342589/1

# %% [markdown]
# 1. 웹페이지의 기본 구성은 html로 시작해서 html로 끝난다.
# 2. head 전체 html에 문서에 대한 기본 정보를 갖고 있다.
# 3. body는 컨텐츠를 포함하고 있다.
